# %%
# -*- coding: utf-8 -*-
#import
import requests
import pandas as pd
import math
from tqdm import tqdm
import yfinance as yf
import exchange_calendars as ecals
from bs4 import BeautifulSoup
import re
import time
import itertools
import csv
import datetime
from multiprocessing.dummy import Pool as ThreadPool
import schedule
from konlpy.tag import Okt
import numpy as np
from keras.layers import Embedding, Dense, LSTM
from keras.models import Sequential
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer
#firebase 관련
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore
from firebase_admin import db
# 멀티프로세싱
import multiprocessing
from multiprocessing import Manager, Pool, freeze_support  
#warning 문자 무시
import warnings
warnings.filterwarnings('ignore')
import keras

# %%
train_data = pd.read_csv("./train.csv")
stopwords = [
    "의",
    "가",
    "이",
    "은",
    "들",
    "는",
    "좀",
    "잘",
    "걍",
    "과",
    "도",
    "를",
    "으로",
    "자",
    "에",
    "와",
    "한",
    "하다"
]
del_list = [
    "오늘의",
    "뉴스",
    "급락주",
    "마감",
    "주요",
    "급등주",
    "증시일정",
    "캘린더",
    "이번주",
    "[포토]",
    "[인사]",
    "상장사",
    "주간",
    "종목",
    "총정리",
    "다음주",
    "슈퍼주총",
    "공모주",
    "돋보기",
    "週間",
    "증권주",
    "코스피",
    "코스닥",
    "KOSPI",
    "KOSDAQ",
     "승리",
    "안타",
    "홈런",
    "패배",
    "야구",
    "축구"
]

url_del_list=[
    "kjmbc",
    "idsn",
    "newsis",
    "sportsseoul",
    "cmbdj",
    "sports",
    "sport"
]
# 형태소분석
okt = Okt()
X_train = []
for sentence in train_data["title"]:
    temp_X = []
    temp_X = okt.morphs(str(sentence), stem=True)  # 토큰화
    temp_X = [word for word in temp_X if not word in stopwords]  # 안쓰는 말 제거
    X_train.append(temp_X)
max_words = 35000
# 토큰화
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
# 정규화
y_train = []
for i in range(len(train_data["label"])):
    if train_data["label"].iloc[i] == 1:
        y_train.append([0, 0, 1])
    elif train_data["label"].iloc[i] == 0:
        y_train.append([0, 1, 0])
    elif train_data["label"].iloc[i] == -1:
        y_train.append([1, 0, 0])
y_train = np.array(y_train)
# 학습
max_len = 20
X_train = pad_sequences(X_train, maxlen=max_len)
model = Sequential()
model.add(Embedding(max_words, 100))
model.add(LSTM(128))
model.add(Dense(3, activation="softmax"))
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
#history = model.fit(X_train, y_train, epochs=10, batch_size=10, validation_split=0.1)
# Out:
# 2022-05-09 23:09:27.251869: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.save('train.h5')

# %%
model = keras.models.load_model("train.h5")

# %%
# 쿼링 보낼 database
if not firebase_admin._apps:
    cred = credentials.Certificate('./firebase_key.json') 
    default_app = firebase_admin.initialize_app(cred)
#firebase_admin.initialize_app(cred, {
#  'projectId': 'capstone-2022-07-dac76',
#})

db = firestore.client()

# %%
XKRX = ecals.get_calendar("XKRX") # 한국 코드
current = datetime.datetime.now()
corr_current = current - datetime.timedelta(hours=9)
global pre_previous
global time_previous
global previous
if(XKRX.is_trading_minute(corr_current.strftime("%Y-%m-%d %H:%M"))):
    previous = datetime.date.today().strftime("%Y-%m-%d")
    time_previous = datetime.date.today().strftime("%Y-%m-%d %H:%M")
    pre_previous = XKRX.previous_session(previous).strftime("%Y-%m-%d")
else:
    previous = XKRX.previous_minute(corr_current.strftime("%Y-%m-%d %H:%M")).strftime("%Y-%m-%d")
    time_previous = XKRX.previous_minute(corr_current.strftime("%Y-%m-%d %H:%M")) + datetime.timedelta(hours=9)
    pre_previous = XKRX.previous_session(previous).strftime("%Y-%m-%d")
    time_previous = str(time_previous.strftime("%Y-%m-%d %H:%M"))

# %%
# 공공데이터포털 api 주소(Without param)
url_stock = "http://api.seibro.or.kr/openapi/service/StockSvc/getKDRSecnInfo"  
api_service_key_stock = [
    "RXhGWArdgsytKaKf0g%2FWxNuo27wXxg4iChLUs9ePc39VvneddFbQ9v9ZXCDWJkdFbhqCvbw9kdMGy%2F%2Bv3it50A%3D%3D",
    "bqvyeN8k%2B8%2BfRLf7p4CNQsUIEL%2BRb4b2YR08MD10RDv3BxHugq6bR1wFEAo8hTau3XgiLcA7bEBoclnMdyBfNQ%3D%3D",
    "zUgkw3obrruAXAW6kZrJnIpK8UUBIrwXrfroSgoDS7NUlSB%2BDz94OTIkkWeP0V%2BzOz81JVtW84bqh1y0HpzcUg%3D%3D",
    "w9Ra19Zqn3%2BLgg2zHoRiZa8zZPdSCXSgFgrgFGUkaYqqQRD6BVKMsUgiRyJqeEuG1pQ86vSioq03IRarAve7sg%3D%3D",
]  # service api key

# 종목 이름 가져오는 코드
def getStockCode(market, code_list):
    """
    market: 상장구분 (11=유가증권, 12=코스닥, 13=K-OTC, 14=코넥스, 50=기타비상장)
    """
    url = f"https://api.odcloud.kr/api/GetStockSecuritiesInfoService/v1/getStockPriceInfo?"
    stock_code = 0
    while True:
        api_decode_key_stock = requests.utils.unquote(
            api_service_key_stock[stock_code], encoding="utf-8"
        )

        params = {
            "serviceKey": api_decode_key_stock,
            "mrktCls": market,
            "numOfRows": 1000,
            "beginBasDt":pre_previous.replace("-", "")
        }

        response = requests.get(url, params=params)
        if(response.status_code != 200):
            print(response.status_code)
            stock_code += 1
            continue
        xml = BeautifulSoup(response.text, "lxml")
        items = xml.find("items")
        item_list = []
        for item in items:
            try:
                item_dict = {
                    "stockName": item.find("itmsnm").text.strip(),
                    "stockCode": item.find("srtncd").text.strip(),
                    "marketCap": int(item.find("mrkttotamt").text.strip()),
                }
                code_list.append(item.find("srtncd").text.strip() + ".KS")
            except AttributeError:
                continue
            item_list.append(item_dict)

        return item_list

# %%
def text_clean(inputString):
    # inputString = inputString.replace("<b>","").replace("</b>","") # html 태그 제거  ## <b> <b/>
    inputString = re.sub(r'\<[^)]*\>', '', inputString, 0).strip() # <> 안의 내용 제거  ## html태그 + 종목명
    inputString = re.sub('[-=+,#/\?:^.@*\"※~ㆍ!』‘|\(\)\[\]`\'…》\”\“\’·]', ' ', inputString) # 특수문자 제거
    inputString = inputString.replace("&quot;"," ").replace("amp;","").replace("&gt; "," ").replace("&lt;"," ")
    inputString = ' '.join(inputString.split())
    
    return inputString

def text_clean_origin(inputString):
    inputString = inputString.replace("<b>","").replace("</b>","") # html 태그 제거  ## <b> <b/>
    inputString = inputString.replace("&quot;"," ").replace("amp;","").replace("&gt; "," ").replace("&lt;"," ")
    inputString = ' '.join(inputString.split())
    
    return inputString
# 기사 날짜 전처리 함수
def formatting_date(date):
    format ='%a, %d %b %Y %H:%M:%S %z'
    date = datetime.datetime.strptime(date, format) # str to datetime
    date = date.strftime("%Y-%m-%d %H:%M:%S") # changing datetime format
    
    return date

# 날짜 -> timestamp = 뉴스의 중복 제거를 위함
def time_to_stamp(date):
    date = date.replace("0900", "0000")
    format ='%a, %d %b %Y %H:%M:%S %z'
    date = datetime.datetime.strptime(date, format) # str to datetime

    return date

# %%
# Naver client key
Naver_client_id=["4NnYXQRzNVwTEO2_rwpd", "8Sbpzhlz4LPc0MPsiaOO"]
Naver_client_secret=["mZP8JBDOBK", "HPqxX8HZfG"]

temp_dt = "Thu, 01 Mar 2022 06:02:00 +0900"
format ='%a, %d %b %Y %H:%M:%S %z'
temp_dt = datetime.datetime.strptime(temp_dt, format) # str to datetime

# %%
# 네이버 api 함수
def api_search(tuple_list, stock, id_key):
    url = 'https://openapi.naver.com/v1/search/news.json' 
    header = {'X-Naver-Client-Id':Naver_client_id[id_key], 'X-Naver-Client-Secret':Naver_client_secret[id_key]}
    param = {'query':stock, 'display':10, 'start':1, 'sort':'date'} 
    # query     : 검색할 단어
    # display   : 검색 출력 건수 (기본 10 / 최대 100)
    # start     : 검색 시작 위치 (기본 1  / 최대 1000)
    # sort      : 정렬순서      (기본 sim : 유사도 / date : 날짜)
    res = requests.get(url, params=param, headers=header)

    pov_or_neg = 0 #긍부정 라벨링 값

    if res.status_code == 200:
        temp = res.json()

        ## 파베에서 제일 최근 기사 time stamp 불러오기
        docs = db.collection(u'wonhyeong').document(stock).collection(u'news').where(u"timestamp", u">", temp_dt).order_by(u'timestamp',direction=firestore.Query.DESCENDING).limit(1).stream()
        bb={}
        for doc in docs:
            bb = doc.to_dict()
        endPoint = bb['timestamp'] if len(bb) >0 else temp_dt
        
        stock_news_list = []

        for index, dict in enumerate(temp['items']):
            news_timestamp = time_to_stamp(dict['pubDate'])
            if endPoint > news_timestamp:
                break
            

            title  = text_clean(dict['title'])
            origin_title = text_clean_origin(dict['title'])
            if any(keyword in title for keyword in del_list):
                continue
            if any(keyword in dict['link'] for keyword in url_del_list):
                continue
            #학습데이터를 통해서 라벨링
            X_test=[]
            temp_X = okt.morphs(str(title), stem=True) #토큰화
            temp_X = [word for word in temp_X if not word in stopwords] #안쓰는 말 제거
            X_test.append(temp_X)
            # tokenizer = Tokenizer(num_words = 35000)
            X_test = tokenizer.texts_to_sequences(X_test)
            X_test = pad_sequences(X_test, maxlen=max_len)
            predict= model.predict(X_test)
            # 호악재 예측값 저장
            pov_or_neg = np.argmax(predict,axis=1)[0]
            predict_labels = np.argmax(predict, axis=1)
            prediction = round(predict[0][predict_labels[0]],2)
            date = formatting_date(dict['pubDate'])
            print(origin_title)
            stock_news_list.append({
                u'date': date,
                u'title': origin_title,
                u'label': str(pov_or_neg),
                u'prediction' : float(prediction),
                u'url':dict[str('originallink')],
                u'timestamp':news_timestamp,
            })

            tuple_list.append((stock ,title ,dict['originallink'] ,date ,pov_or_neg))
            
            # print(stock ,title ,dict['originallink'] ,date ,pov_or_neg)
    else:
        print("Error Code:" + str(res.status_code)+" Stock name is "+ str(stock))
        
        
    def AddFirebaseToNews(item):
        db.collection(u'wonhyeong').document(stock).collection(u'news').document().set(item)

    pool = ThreadPool(10)

    for _ in pool.imap_unordered(AddFirebaseToNews, stock_news_list):
        pass
    
    ## 개수 카운트
    time_hour = datetime.datetime.now() - datetime.timedelta(hours=1)
    docs = db.collection(u'wonhyeong').document(stock).collection(u'news').where(u"timestamp", u">", time_hour).stream()
    
    TimeNewsCount =0            #시간당 기사 개수
    TimePerPositiveNewsCount=0  #시간당긍정개수
    TimePerNegativeNewsCount=0  #시간당부정개수
    DayNewsCount=0              #하루 기사 개수
    bb={}
    for doc in docs:
        TimeNewsCount+=1
        bb=doc.to_dict()
        if bb['label'] == "0":
            TimePerNegativeNewsCount+=1
        elif bb['label'] =="2":
            TimePerPositiveNewsCount+=1

    time_day = datetime.datetime.now()-datetime.timedelta(days=1)
    docs = db.collection(u'wonhyeong').document(stock).collection(u'news').where(u"timestamp", u">", time_day).stream()
    bb={}
    for doc in docs:
        DayNewsCount+=1

    try:
        news_temp = db.collection(u'wonhyeong').document(stock)
        news_temp.update({
            u'DayNewsCount': DayNewsCount,
            u'TimeNewsCount': TimeNewsCount,
            u'TimePerPositiveNewsCount': TimePerPositiveNewsCount,
            u'TimePerNegativeNewsCount':TimePerNegativeNewsCount,
        })
    except:
        pass

# %%
# 종목들 전역변수로 가져오기
company=[]
def get_companylist():
    global code_list
    code_list = []
    item_list = getStockCode("KOSPI", code_list)
    item_list.append({
        "stockName": "코스피",
        "stockCode": "^KS11",
        "marketCap": 0,
        "updatedTime" : time_previous,
        })
    item_list.append({
        "stockName": "코스닥",
        "stockCode": "^KQ11",
        "marketCap": 0,
    })
    code_list.append("^KS11")
    code_list.append("^KQ11")
    global company
    company=item_list

# %%
def stock_information_getTime():
    # start에는 장이 열리는 날 - 하루가 들어가야 함
    #날짜반영
    XKRX = ecals.get_calendar("XKRX") # 한국 코드
    current = datetime.datetime.now()
    corr_current = current - datetime.timedelta(hours=9)
    global pre_previous
    global time_previous
    global previous
    if(XKRX.is_trading_minute(corr_current.strftime("%Y-%m-%d %H:%M"))):
        previous = datetime.date.today().strftime("%Y-%m-%d")
        time_previous = datetime.date.today().strftime("%Y-%m-%d %H:%M")
        pre_previous = XKRX.previous_session(previous).strftime("%Y-%m-%d")
    else:
        previous = XKRX.previous_minute(corr_current.strftime("%Y-%m-%d %H:%M")).strftime("%Y-%m-%d")
        time_previous = XKRX.previous_minute(corr_current.strftime("%Y-%m-%d %H:%M")) + datetime.timedelta(hours=9)
        pre_previous = XKRX.previous_session(previous).strftime("%Y-%m-%d")
        time_previous = str(time_previous.strftime("%Y-%m-%d %H:%M"))
        
stock_information_getTime()

# %%
def stock_pretreatment():
    # item_list에 각 필드들 쿼링
    for j in tqdm(company):
        stockCode = j["stockCode"]
        if j["stockCode"] != "^KS11" and j["stockCode"] != "^KQ11" :
            stockCode += ".KS"
            
            
        j["stockPrice"] = float(data["Close"][stockCode][1])
        j["stockLowPrice"] = float(data["Low"][stockCode][1])
        j["stockHighPrice"] = float(data["High"][stockCode][1])
        j["stockVolume"] = float(data["Volume"][stockCode][1])
        j["stockOpenPrice"] = float(data["Open"][stockCode][1])
        j["stockClosingPrice"] = float(data["Close"][stockCode][0])
        j['stockChange'] = float(data['Close'][stockCode][1] - data['Close'][stockCode][0])
        j['stockPerChange'] = float((data['Close'][stockCode][1] - data['Close'][stockCode][0]) / data['Close'][stockCode][0] * 100)


    # 상장폐지 / 거래중지 종목 리스트에서 제거
    for i in company:
        if math.isnan(i['stockPrice']) or math.isnan(i['stockLowPrice']) or math.isnan(i['stockHighPrice']) or math.isnan(i['stockVolume']) or math.isnan(i['stockOpenPrice'])or math.isnan(i['stockClosingPrice'])or math.isnan(i['stockChange'])or math.isnan(i['stockPerChange']):
            company.remove(i)

    # round 처리로 2자리수까지 보여짐
    # nan 처리 해주고 나서 돌려야해서 필요한 코드
    for j in tqdm(company):
        stockCode = j["stockCode"]
        if j["stockCode"] != "^KS11" and j["stockCode"] != "^KQ11" :
            stockCode += ".KS"
        j["stockPrice"] = float(round(data["Close"][stockCode][1], 2) )
        j["stockLowPrice"] = float(round(data["Low"][stockCode][1],2))
        j["stockHighPrice"] = float(round(data["High"][stockCode][1],2))
        j["stockVolume"] = float(round(data["Volume"][stockCode][1],2))
        j["stockOpenPrice"] = float(round(data["Open"][stockCode][1],2))
        j["stockClosingPrice"] = float(round(data["Close"][stockCode][0],2))
        j["stockChange"] = float(round(
            data["Close"][stockCode][1] - data["Close"][stockCode][0],2)
        )
        j["stockPerChange"] = float(round(
            (data["Close"][stockCode][1] - data["Close"][stockCode][0])
            / data["Close"][stockCode][0]
            * 100,2)
        )
        j["DayNewsConut"] = 0
        j["TimeNewsCount"] = 0
        j["TimePerPositiveNewsCount"] = 0
        j["TimePerNegativeNewsCount"] = 0

# %%
def firebase_transaction():
    db = firestore.client()

    def AddFirebase(item):
        db.collection(u"wonhyeong").document(item["stockName"]).set(item)

    pool = ThreadPool(10)

    for _ in tqdm(pool.imap_unordered(AddFirebase, company), total=len(company)):
        pass

    pool.close() 
    pool.join()

# %%
print("run")
stock_information_getTime()
# Out:
# run

# %%
get_companylist()

# %%
data = yf.download(code_list, start=pre_previous)
# Out:
# [*********************100%***********************]  942 of 942 completed
#
# 4 Failed downloads:
# - 096300.KS: No data found for this date range, symbol may be delisted
# - 094800.KS: No data found for this date range, symbol may be delisted
# - 152550.KS: No data found for this date range, symbol may be delisted
# - 00279K.KS: No data found for this date range, symbol may be delisted

# %%
stock_pretreatment()
# Out:
# 100%|██████████| 942/942 [00:04<00:00, 218.62it/s]
# 100%|██████████| 471/471 [00:02<00:00, 219.55it/s]

# %%
firebase_transaction()
# Out:
# 100%|██████████| 471/471 [00:14<00:00, 32.21it/s]

# %%
start = time.time()
tuple_list=[]
tuple_list.append(("stock" ,"title" ,"url" ,"date" ,"pov_or_neg"))
id_key = 0
st = time.time()


pool = ThreadPool(10)
for _ in tqdm(pool.starmap(api_search, [(tuple_list, stock["stockName"], id_key) for stock in company],), total=len([(tuple_list, stock["stockName"], id_key) for stock in company])):
    pass

pool.close() 
pool.join()
#### Pool() 프로세스 수는 변경 가능
print("quering end, it takes to ",int(time.time() -st),"s" )
# 쿼링 포함 15분 제한
print("sleep ")
end = time.time()
rest_time = 900 - (end-start) if 900-(end-start) >0 else 0
time.sleep(rest_time)
# Out:
# sibal
# sibal
# sibal
# sibal
# sibal
# sibal
# sibal
# sibal
# sibal
# sibal
# “10원이라도 더…” 하락장에 우선주로 몰린 투심
# “10원이라도 더…” 하락장에 우선주로 몰린 투심
# 백화점·홈쇼핑 없이 31년간 장수 비결... 착한 제품·경영
# [장외주식] 엘지씨엔에스 강세
# 삼화페인트, 페인트 2종 美USDA 인증 획득
# 티맵, 美조비항공과 한국형 도심항공교통 서비스 개발 착수
# 에이프로젠MED·에이프로젠제약, 모두 보합세…특히 에이프로젠제약 소폭 상승
# '韓 우선주 집중 투자' WKOF, 지난해 NAV 수익률 -1.4%
# ‘집꾸족’ 잡아라… 페인트업계, 친환경 제품 경쟁
# 에이프로젠MED·에이프로젠제약, 모두 보합세…특히 에이프로젠제약 2거래일 ...
# 배당주의 시대 왔나…역대급 시가배당률에 중간배당도 ‘짭짤’
# 폐차 유리 활용해 페인트 만들고 식물성 소재 사용도 늘려
# “10원이라도 더…” 하락장에 우선주로 몰린 투심
# 인텔리안테크, 1분기부터 달린다
# 배당주의 시대 왔나…역대급 시가배당률에 중간배당도 ‘짭짤’
# 변동성 커진 증시, 고배당주에 쏠린 '투심'
# 삼양그룹 수당재단, 제31회 수당상 수상자 선정
# sibal
# 삼양그룹 수당재단, 제31회 수당상 수상자 선정
# 증권사 실적부진에 울상··· 줄줄이 '신저가' 경신
# 삼양그룹 수당재단, 제31회 수당상 수상자 선정
# [Who Is ?] 안철수 윤석열 대통령직인수위원회 위원장
# sibal
# sibal
# 종합상사들, '코로나 경제구조'서 부활가
# [특징주] GS글로벌 3% 상승 '러시아, 수출 금지 품목에 석탄 포함되나'
# [특징주] GS 주가↑...어디까지 오를까?
# sibal
# sibal
# [매매의 기술] 글로벌 석탄 공급 비상에 주목! 'GS글로벌'vs증강현실發 실적개...
# sibal
# [특징주] 러시아 보복 수출 제재 관련 원자재株 강세
# GS글로벌, 3거래일만에 가파른 상승세로 4% 상승…공매도 수량 106주
# GS글로벌, 주가 '급등'…러, 석탄 수출 막나
# 경유값 '한숨만...'
# sibal
# 한화임팩트 울산공장, 초록우산어린이재단 인재양성아동 사업 후원금 720만원...
# 유류세 인하에도 대구·경북 경윳값 상승세 지속
# [GS그룹] 최근 1개월 등락률은…GS 9.15% 상승 '주목'
# 최시원, 한화호텔X유니세프 '체인지 포 칠드런' 캠페인 참여
# sibal
# sibal
# 러시아 원자재 수출금지 품목 추측 난무...요동치는 원자재 관련주
# 강원 휘발유 가격 1,947원…유류세 인하로 하락
# PG사가 현지 법인 세워 ‘셀러 일본진출’ 돕겠다 나선 이유
# [특징주] 고려산업, 러시아 종전선언 할까...기대감 속 주가는?
# 용산소방서, 금양초등학교 119청소년단 발대식
# sibal
# 휘발유보다 비싼 경유 속출…화물 운송업계 '시름'
# 이제상 전 대구시경제보좌관, 무소속 대구시의원 출마
# 한화, 한국판 NASA 우주학교 문 연다...카이스트와 우주 영재 육성 발굴
# 화학 상장기업 기업평판 우수기업 2022년 5월 발표
# 인터로조, 대원제약, 세아제강 적정주가 상향비율 TOP3…코윈테크, DI동일 뒤...
# “10원이라도 더…” 하락장에 우선주로 몰린 투심
# 제약·바이오기업 PBR, SK바이오팜 15.7배‥ BPS, 종근당홀딩스 `최고`
# 주총시즌 돌입…제약바이오 화두는 '경영 승계·신사업'
# 진주 지수초등학교 개교 100주년 기념행사
# [특징주] 포드의 리비안 주식 매각 소식에 국내 테마주↓
# 휴비츠, 매월 최대 실적 경신…中 셧다운 해제 가능성에 3분기 추가 매출 기...
# 종근당, 81년 업력에 절대 포기하지 않는 '3가지'
# 제약·바이오 주총 관전포인트…'수장교체·현금배당' 눈길
# [브랜드평판] 철강 상장기업 순위, 1위 포스코홀딩스 2위 현대제철 3위 KG스틸
# 대한뉴팜, 3년만에 신약 개발 도전…위식도역류질환 시장 도전
# GS그룹 허정구계·허준구계 4세, 경영성과 선의의 경쟁 중
# sibal
# “휴비츠, 올 들어 매월 사상 최대 매출 기록”
# [조세] 세무서 직원 안내로 스톡옵션 행사이익에 종소세 아닌 양도소득세 납...
# 포스코홀딩스, 5월 철강 상장기업 브랜드평판 1위
# 코로나19 확진자 감소세 정체기...미국 가을께 1억명 신규확진 전망
# [단독] GS그룹 지배구조, 지주사 지분 변동···'허정구계' 16.39%, '허준구...
# sibal
# 증권사 '신용융자 금리' 고공행진…업체간 격차 2배
# 일동홀딩스 빛난 4월, 한미약품ㆍJW중외제약ㆍ대웅제약 선전
# 철강 상장기업 브랜드평판 5월 빅데이터 분석결과...1위 포스코홀딩스, 2위 현...대웅종합건설, 글로벌 청소년 리더센터 신축 건설공사 수주 유력
#
# [GS그룹] 5월 등락률 살펴보니…GS 6.86% 상승 '눈길'
# 제55회 황토현 동학농민혁명 기념제
# sibal
# FOMC 후폭풍에 불안감 최고조…공포에 사라?[선데이머니카페]
# [특징주] '종근당' 호실적 공시에 주가↑
# 포스코홀딩스, 철강 상장기업 브랜드평판 5월 톱… 평판지수는 하락
# '변호의 신' 황보라, 10년 연인 차현우 향한 신뢰 결혼 결심 흔들린 적 NO
# LG 구인회·삼성 이병철 다닌 지수초 '100주년'…쟁쟁한 동문 모인다
# 법적 검토 이근, 보여주기식 활동 비판에 반박...'강경 대응 예고'
# 수원시약, 지역 아동·어르신에 사랑의 의약품 지원
# 대기업집단 브랜드평판 1~3위는
# 온탕과 냉탕 오간 '서학개미'… 안심은 아직
# '종근당 예술지상 2022' 작가 선정…신진 미술작가 창작 지원
# [특징주]CPTPP 가입 기대감에 철강주 강세
# ♥차현우와 결혼발표 하고싶다 황보라, 파격 시청률 공약('변호의 신')[종합...
# 먹는 코로나 치료제 기대… 항바이러스제 관건은 가격
# 한국족보박물관에 족보 기증 잇따라
# [팝콘스타클럽] 1분기 어닝 서프라이즈 기록 소식에 급등한 '골프존'
# 2차전지 등 이익 내는 성장주 투자해야 ...동학개미 투자전략은?
# 난 세금으로 축의금을 받았다 [삶과 문화]
# [제약업계 소식] 4월 28일
# 대웅제약, 위식도역류질환 치료제 '펙수클루' 출시 임박...신약 모멘텀 본격화
# '10년째 열애 중♥' 황보라, 올해 하정우랑 식구 되려나... 깜짝 발언 했다
# “영장에 안 적힌 곳 압수수색, 동의받았다면 적법”
# sibal
# 하이트진로, 올해도 취약계층 이동성 보장 위한 차량 지원
# 동성제약 윤경미 마케팅본부 주임
# 보락 주가 3%↑…LG화학 1분기 매출액 때문?
# 하이트진로, 올해도 취약계층 이동성 보장 위한 차량 지원
# 맞춤형 헬스케어 서비스 열린다…기업들 속속 참전[마이데이터 시대①]
# LG그룹 구광모 회장, 부인 정효정 씨 결혼스토리 재조명
# sibal
# [화촉] 윤경미 동성제약 마케팅본부 대리(5/28)
# 하이트진로, 차량 기증 기관 공모… 취약계층 이동성 보호
# 커넥트디아이 '약꿍톡' 무료 약사 상담, 심야 서비스 확대
# 보락 주가 2%↑…LG화학 때문에 강세?
# '여성호르몬제 CMO 독식'...지엘팜텍, 고성장 열차 올라타나
# 반도체 상장기업 기업평판 우수기업 2022년 5월 발표
# 이주의 주식시장은? 러시아-우크라이나 전쟁 여파, 사료·곡물주 다시 급등.....
# sibal
# 병원 가기 부끄러워 …소리없이 커진 '먹는 치질약' 시장
# sibal
# 이재현의 CJ, 다시 제약·바이오
# GC녹십자, 이한주 디스커버리 유닛장 영입…보령컨슈머헬스케어, '브링 식물성...
# 고가 경품보다 인기 좋네…편의점 대세 '주식 마케팅'
# '약꿍톡' 무료 약사 상담, 심야 서비스 확대
# 美 연준, 금리 0.5% 대폭 인상···국내 제약사 주가 ‘휘청’
# [특징주] 인도네시아 팜유 수출 중단에 식료품株 일제히 급등
# 동성제약, '록소앤겔' TV광고 온에어
# 권상우, ‘위기의 X’ 출연 확정…성동일·임세미와 코믹 호흡
# ‘롯데바이오로직스’ 상표 등록…롯데, 바이오 CMO 사업 속도
# 강세 꺾인 사료株…대한제당·현대사료 하락세 [증시이슈]
# sibal
# 임세미 ‘위기의 X’ 출연확정, 권상우와 부부 호흡
# 동성제약, 남궁민 내세워 '엘보우엔 록소앤겔' 광고 개시
# 6월 ASCO 등 굵직한 바이오 행사 줄줄이... 우리 기업들의 성과, 기대해도 좋...
# 10대그룹 총수 포함 재계 80명 尹취임식 참석
# 제약업계, NASH 치료제 개발 본격화…글로벌 ‘게임 체인저’ 도전장
# 역량 키우고 우군 넓히는 '카카오헬스케어'
# [특징주] 에이치엘비 소폭 하락 '난소암 치료제 판매 시작'
# 1분기 추정 매출 2.5% 상승…해외에서 잘 나가는 삼성바이오에피스
# 1분기 실적 웃었다… 허승범 삼일제약 부회장, 도약 시동 걸까
# sibal
# '반려견 난치병' 해결 나선 지엔티파마·HLB생명과학···글로벌 공략 기대
# '위기의 X' 권상우-임세미-성동일, 현실 대격변…공감 예고
# 동성제약, ‘엘보우엔 록소앤겔’ TV광고 온에어
# 尹 취임식, 이재용 등 10대 그룹 초청…새 정부 이 부회장 사면 가능성은
# '신약이 답이다' 신약 확보에 열 올리는 중견 제약사
# sibal
# sibal
# HLB, 난소암 치료제 '아필리아' 독일 판매 시작...'글로벌 항암제 시판 본격화...
# 권상우X임세미X성동일, '위기의 X' 출연…하반기 공개 예정 [공식]
# 동성제약 ‘록소앤겔’, 신규 TV광고 온에어
# [ET라씨로] 모바일 간편결제 신사업 추진한 하인크코리아, 주가 '고공행진'…...
# sibal
# 분기배당부터 차등배당까지...증시 부진 속 고배당주 관심
# 먹는 코로나 치료제 기대… 항바이러스제 관건은 가격
# sibal
# 필리핀 시오노기 코로나19 경구치료제 'S-217622' 임상 중단 무슨일?
# [미리보는 이데일리 신문]갑질 구글에 벌금만…형사처벌은 뺀 터키
# 백악관 올 하반기 코로나 재확산…1억 명 확진 우려
# sibal
# 산업銀 사령탑 이동걸, 4년 8개월간 구조조정 11곳 성과
# 먹는 치료제, 스텔스오미크론 잡는다… 치료제 개발 역량 강화해야
# 에디슨EV 채권자, 파산 신청 취하 공시
# 쌍용차 인수예정자 선정 임박, KG그룹 유력하지만 자금동원력이 관건
# [더벨][중견 제강사 리포트]고려제강 3세 홍석표 사장, 이사회 진입은 언제
# 오미크론 유행에 기침가래약 특수
# [좋은정보의 '황금 맥점'] 쌍용차 인수전 참여한 건설소재와 비료의 제조·판...
# sibal
# 마스크 해방, 5월 가족과 봄나들이하기 좋은 핫 플레이스
# sibal
# 쌍용차, SUV 'J100'으로 부활 노린다
# 미 백악관, 올 하반기 코로나19 확진자 1억 명 넘는다…다시 마스크 써야
# 중공업·산업재·화장품 ETF 약세장서 '질주'
# sibal
# [주식] 속도 내는 쌍용차 재매각…KG스틸·KG케미칼 주가는?
# [브랜드평판] 철강 상장기업 순위, 1위 포스코홀딩스 2위 현대제철 3위 KG스틸
# 푸디스트, 민간 최초 육해공군 3군 급식 운영
# 올 1분기 코로나19 관련 의약품 ‘대박’…최대 200%↑ 성장
# 아모레는 지금(하) 장녀 서민정의 절묘한 '아빠찬스'와 경영승계
# KG스틸·KG케미칼, 모두 하락세…특히 KG스틸 가파른 하락세로 4% 낙폭
# 포스코홀딩스, 5월 철강 상장기업 브랜드평판 1위
# 美 경구용 코로나 치료제 복용 환자, 장기 후유증 완화 경험
# 음주운전 사고 후 차 버리고 도주… 경찰, 20대男 불구속 입건
# MSCI 정기변경 임박…대규모 자금 어디로 가나
# 약세장 속 수소 관련주는 수소법 타고 '훨훨'… 두산퓨얼셀 등 상승
# [쌍용차 인수] 쌍방울·광림·KG스틸·KG케미칼 주가 승자는?
# '쌍용차 인수 실패' 에디슨EV… 채권자들 파산신청 취하
# 철강 상장기업 브랜드평판 5월 빅데이터 분석결과...1위 포스코홀딩스, 2위 현...
# sibal
# 지미추, 2022 썸머 컬렉션 선봬...화려하고 대담 FLEX
# 기준금리 인상 가능성··· 보험주 강세 이어질 것
# 일동제약 주가 상승하나 ...정부 코로나19 치료제 효능 유지
# “10원이라도 더…” 하락장에 우선주로 몰린 투심
# 컴투스홀딩스, 투자의견 상향비율 TOP1…씨젠, 현대두산인프라코어, 바이넥스...
# [어제의 특징주]수소법 통과 기대감에 두산퓨얼셀 등 수소株 '고공행진'...SK...
# 배당성향 5%인 고려제강… 홍영철 회장 등 ‘가족 회사’는 87%만취한 남성, 길 가던 여성 '묻지마 폭행'... 뺑소니 사고로 은폐 시도
#
# KG스틸, 주가 급락세 보여…쌍용차 인수제한서 제출 'D-2'
# 일상회복으로 바쁜 철도 물류수송
# 러시아 산불에 제지주 강세…'매각 추진' 페이퍼코리아 '上'
# 대한제당우, 주가 '급락'…러·우 종전 가능성에 휘청
# 서울 구청장 대진표 윤곽···‘현역’ 민주 vs ‘전직’ 국힘[6·1지방선거...
# 지연 화보 “티아라, 언제든지 꼭 다시 뭉쳐 활동하고 싶었다”
# 카카오게임즈, '이터널리턴' 플레이엑스포 단독부스 참여
# 티라아 지연, 봄의 여신[화보]
# sibal
# sibal
# 카카오게임즈 ‘이터널 리턴’, 플레이엑스포 단독 부스 행사 개최
# 삼성 이재용 부회장, CEO 브랜드평판 5월 빅데이터 1위...정의선 회장 뒤이어
# 카카오게임즈 '이터널 리턴', 플레이엑스포 단독 부스 운영
# 삼성, 대기업집단 브랜드평판 이달 1위... 평판지수는 10.90% 하락
# 식판에 ‘뻥이요’ ‘꼬북칩’… 달궈진 4조3000억원 급식시장
# 카카오게임즈 ‘이터널 리턴’, 플레이엑스포 참여
# 카카오게임즈 ‘이터널 리턴’, 플레이엑스포서 단독 부스 운영
# [6.1지방선거]서울시 구청장 후보 ‘오세훈 마케팅’ 바람 거센 이유?
# [경기시론] 도시와 대관령에서 토닥토닥
# 일동제약ㆍ신풍제약우, 1분기 주가상승률 3ㆍ4위
# sibal
# 월드옥타 프랑크푸르트지회, 기업세무회계 세미나 개최
# sibal
# 11개 제약주, 유가증권시장 2월 월간 주가상승률 Top100
# 1분기 실적 상위사 '빵빵' 중견사 '홀쭉'…GC녹십자 '깜놀 성장'
# 마지막 접경역 구텐퓌르스트
# 美 연준, 금리 0.5% 대폭 인상···국내 제약사 주가 ‘휘청’
# sibal
# sibal
# 나노소재 기술개발 포항지역이 이끈다
# sibal
# sibal
# 갤러리 상상헌, 한독교류전 ‘꽃으로 그대가 왔다’ 개최
# '크다고 쪼개면 안돼요'…알약이 각양각색인 이유
# 투자업체, '제넥신 中 파트너사' 아이맵 잇단 매입 행렬
# 코튼데이 2022 개최, 미래를 향한 협력 강조
# '로컬식탁' 남희석 주우재, 딸들의 연애코치
# 폴리텍대학 동부산캠퍼스, 부산권 취업동아리 선정
# [단독] 권영세 처남도 논란 싸인 중국 커피 사업에 투자했다
# '로컬식탁' 보령 맛집 소개에 남희석 등장...'보령 1호 아들'
# 누적 강수량 평년보다 적어…경상·강원 약한 기상가뭄
# 안심지역 없다 ··· 지선 달아올라
# TYM, 1분기 매출 3004억…'어닝 서프라이즈'
# 대상, SK네트웍스, 삼화콘덴서, 금호건설, 대한유화 EPS 하향 조정 상위
# sibal
# '로컬식탁' 스페셜 게스트 남희석 출격...보령 맛집 찾는다
# 시민단체 민주당 후보 '공천=당선'이라는 자만에 빠져선 안 돼
# [주식 초고수는 지금] 美 정책 수혜 기대감에…대한전선 매수 1위
# sibal
# [브랜드평판] 전기제품 상장기업 순위, 1위 LG에너지솔루션 2위 삼성SDI 3위 ...
# “김관영 후보 공약 일부 부적절…‘카지노 논란’ 입장 밝혀야”
# [Who Is ?] 김상열 호반장학재단 이사장 겸 서울미디어홀딩스 회장
# ㈜한국프리시전웍스, 창립 49주년 기념 '사랑의 헌혈 캠페인' 동참
# [LG서 독립 1주년…LX그룹 구본준호 순항] LX, 코로나19 위기 뚫고 영업익 3배...
# '중남미 펀드' 나홀로 질주…원자재값 뛰자 수익률 '삼바춤'
# 3년 수익률 53%…우리 아이 결혼 자금 이걸로 마련해볼까?
# 올해 연간 물가전망치 줄줄이 상향조정…4.6% 예상도
# [핫 이슈 테마주] 사회적 거리두기 완전 해제 검토...영화 및 화장품 테마 상...
# 대우조선해양건설 장세웅 신용구 각자대표체제로, “경영효율성 향상”
# 현대글로비스, 항공화물운송사 브랜드평판 1위…한진·CJ대한통운 순
# 삼성전자의 배신 …어린이펀드 1년 수익률 –13%, 자금도 순유출
# 쌍용차 상장폐지, '14일' 결론은? [사자경제]
# 현대글로비스, 항공화물운송 상장기업 4월 1위…한진·CJ대한통운 순
# 한국앤컴퍼니 계열사 한국네트웍스, 조영민 대표 취임
# 건자재업계, '고부가·신사업' 투트랙으로 호실적 이어간다
# [특징주] 송원산업, 영업이익 증가…주가 상황은?
# 호반건설 김상열 회장 일감 몰아주기 의혹···공정위 조사 중
# sibal
# 에이수스, 5월 한 달간 게이밍 모니터 PC방 대상 10+2 추가 증정 이벤트 진행
# 재계, '尹 서초동 인맥' 모시기···檢출신 사외이사 줄영입
# 한미 금리 역전 눈 앞…한은도 '빅스텝' 밟을까
# 유수홀딩스, 송영규 사내 이사 재선임
# 이직 꿈꾸는 직장인이라면 '리멤버 커리어'를 리멤버하라
# sibal
# 싸이버로지텍, 물류데이터 통합플랫폼 ‘스마트링크’ 업그레이드 버전 출시
# 싸이버로지텍, 물류 데이터 통합 플랫폼 '스마트링크' 업그레이드 버전 출시
# NC 루친스키 '대체 불가 투수' 경쟁 선두
# SSG 한유섬·NC 루친스키, 2022 KBO 리그 4월 '쉘힐릭스플레이어' 선두 경쟁
# 석유·가스기업 브랜드평판, SK이노베이션 '1위'
# sibal
# sibal
# 종합상사들, '코로나 경제구조'서 부활가
# '中 봉쇄발' 국제유가 100달러 붕괴...SK이노베이션·에쓰오일등 정유株 줄하...
# sibal
# [LG서 독립 1주년…LX그룹 구본준호 순항] LX, 코로나19 위기 뚫고 영업익 3배...
# 석유가스 상장기업 브랜드평판 4월 빅데이터 분석결과...1위 SK이노베이션, 2...
# 배터리소재 中의존 줄이는 테슬라… K배터리도 공급망 다각화
# 건자재업계, '고부가·신사업' 투트랙으로 호실적 이어간다
# LX인터, 인도네시아 니켈 광산 인수 나서는 까닭은
# [LG그룹] 최근 1개월 계열사 등락률은?…LX인터내셔널 4.16% 상승 '눈길'
# 하나금융·SK텔레콤·포스코…6월말 중간배당 매력 ‘쑥’
# sibal
# sibal
# sibal
# [핀셋+] [롯데] 헬스케어 수장에 M&A 전문가 선임, 왜?
# '원재료 찾아 삼만리' 기업 간의 현대판 도원결의
# 장 중 기업공시[4월 29일]
# '전 세계에 딱 세 자루'…프란치스코 교황도 반한 한국 볼펜
# [현대차그룹] 한주간 시가총액 1조3600억 감소…현대로템, 소폭 상승 '눈길'
# 환율 급등 시기, 중소형주 투자처로 부상하나
# OCI 군산공장, 자매결연마을에 후원금 전달
# 안랩 가파른 상승세 이어 써니전자·까뮤이앤씨, 안철수 관련주 모두 상승세
# [특징주] '한화에어로스페이스' 차세대 우주 발사체 개발 소식에 주가는?
# [주식] 삼성중공업·삼성중공우, 주가 ‘상승’…배경 살펴보니
# sibal
# 대우부품, 서중호 단독 대표이사 체제로
# '글로벌 스탠다드 탄소중립', 국내 5대기업 RE100 잰걸음
# OCI 군산공장, 자매결연마을 후원금 전달
# 바이오헬스 이슈 총망라 'BIO KOREA 2022', 실시간 라이브로 포스트 코로나 시...
# 급등하는 환율, 1300원 전망까지… 외국인 민감도 낮은 중소형주 주목
# 안랩·써니전자 상승 반해 까뮤이앤씨 하락, 안철수 관련주 희비 엇갈려
# [기업탐구]한화시스템, 에어모빌리티·위성통신…신사업 시너지 '훨훨'
# [특징주] '시외 급등' 삼성중공업·삼성중공우, '드릴십' 잔가지 쳐내고 주가...
# [더벨]'등급강등' 디티알오토모티브, 'P-CBO'로 조달 선회
# 현대차그룹, 현대로템·현대글로비스·기아 상승 '눈길'
# 이런 날 올줄 알았죠 …문구 체험매장 북적
# 테슬라·리비안·루시드, 주가 나란히 10%대 '폭락'…전기차株 무슨 일?
# 씨젠, 생명과학서비스 상장기업 5월 브랜드평판 1위 차지
# 安 대통령→총리, 이번엔 경기 분당갑?…또 다시 들썩이는 관련주
# 尹정부 출범 D-1...'원자력' '방위산업' 떠오른다
# 삼성중공업, 시간외 주가 '급등'…드릴쉽 매각에 훨훨
# sibal
# [업계만화경] '기록을 넘어 상상을 그려내다' 모나미 콘셉트스토어 성수점이 ...
# 한국투자 환율 상승세 지속되면 대형주보다 중소형주가 안정적
# 테슬라 '급등', 리비안·루시드·니콜라 '급락'…전기차주 '희비' 갈려
# 안랩 5% 급등 이어 써니전자 상승 VS 까뮤이앤씨 소폭 하락, 안철수 관련주 희...
# 씨젠, 생명과학서비스 브랜드평판 1위…휴마시스·엔케이맥스 순
# 삼성중공우, 주가 '상한가'…'애물단지' 드릴쉽 매각에 훈풍
# 계속된 미사일 도발, 방산주 더 날아오를까
# [특징주] 휴니드 주가 상승...왜 오른 것일까?
# [이승윤의 ‘공간은 경험이다’] 저출산의 시대, 경험의 공간으로 위기를 돌파...
# 테슬라·리비안·니콜라·루시드, 일제히 '급등'…배경은?
# 생명과학서비스 상장기업 브랜드평판 1~3위는
# 잘나가는 '삼바에피스', 롯데도 '바이오' 참전
# 삼성중공우, 휴림로봇·로보로보·유진로봇 등 로봇주 시간외 거래 강세
# [아침논단]항공우주청 설립과 경상국립대의 역할
# 리비안·루시드·니콜라, 배터리 공급 부족 우려에 '휘청'…테슬라 나홀로 '훨...
# 호재도 악재도 '더블'…우선주 투자 주의보
# 현대중공업, 조선 상장기업 브랜드평판 2022년 5월...1위
# 젊어진 페인트업계, 온라인 마케팅으로 MZ세대 '눈도장'
# K-콘텐츠에겐 오히려 기회 …콘텐트리중앙 '강세'
# ubc 울산방송) 정제마진 초강세..설비 '풀가동'
# 영국 이코노미스트 “윤석열, 경험·인기 부족...청년·미중관계 등 난제 산적...
# 구자은 전기차, LS 신성장 동력으로
# 현대중공업, 조선 상장기업 브랜드평판 5월 톱… 평판지수도 큰폭 상승
# 종자사업 6년만의 흑자…노루그룹 신사업 열정, 열매 맺었다
# '플랜B'로 LFP 개발 착수…中 배터리 견제
# LS그룹 구자은 회장 군포 공장 생산 전기차·ESS 부품, 그룹의 신성장 동력...
# 이코노미스트 尹 경험도, 인기도 부족…가장 높은 부정 평가율로 임기 시작
# 조선 기자재社 세진중공업·성광벤드 주목
# [특징주] '시디즈' 가격 줄줄이 상승에 투자자 기대감↑
# 노루페인트, 가치 캠페인 '노루 아뜰리에' 참여자 1만5000명 돌파
# [마켓인]SK에너지, 최대 5000억 규모 공모채 발행…회사채 차환 목적
# 구자은 LS 회장, EV코리아 공장 준공식 참석
# 英이코노미스트 “尹당선인, 경험·인기 부족…집값·청년·여소야대 등 난제...
# [단독] 캄포소파도 오른다 …신세계까사, 1000여개 품목 평균 6.3%↑
# sibal
# 씨씨오씨, ‘컬러 픽쳐스, 마일즈 알드리지’ 사진전 진행
# 구자은 LS 회장, EV코리아 공장 준공식 참석…전기차 힘 싣는다
# 윤석열 앞 난제 산적…청년·미중·북한·여소야대 이코노미스트&gt;
# “10원이라도 더…” 하락장에 우선주로 몰린 투심
# [Weekly New쇼핑] 황금 연휴 '성수동' 나들이 어때요?
# 에너지 가격 상승에 주목받은 조선주… 기자재까지 관심 확장
# sibal
# [김성재 칼럼] 미국 경제, 1분기 역성장 딛고 호전될 수 있을까?
# 노루페인트, 가치 캠페인 '노루 아뜰리에' 참여자 1만 5000명 돌파
# [G-브리핑] 위메이드, 위믹스 3.0 글로벌 쇼케이스 티저 페이지 공개
# “선가 상승으로 조선 업황 ‘맑음’…기자재株 주목”
# [중기소식]하이메 아욘 '암체어·테이블' 국내 출시 등
# 젠지 이스포츠, 독일 게이밍 기어 브랜드 로캣과 파트너십 재계약 체결
# 일승, LNG 호황 힘입어 환경장비 대량 수주
# 일진하이솔루스, 3% 낙폭에 4만원선 위태…공매도 수량 100주대
# [굿모닝! 글로벌 증시] Fed의 빅스텝 금리인상과 베이징 봉쇄 소식에 증시 압...
# sibal
# sibal
# 젠지 이스포츠, 독일 게이밍 기어 브랜드 로캣과 파트너십 재계약 체결
# [유철규 칼럼] 환율급등은 미국의 꽃놀이패?
# 노루페인트, 가치 캠페인 '노루 아뜰리에' 참여자 1만5000명 돌파
# [신규 대기업집단 분석] 일진그룹 형제 간 독자 경영체제…계열분리 굳이 할까
# 복지부, 동아에스티에 과징금 108억 부과…이유는 리베이트
# 젠지 이스포츠, 독일 게이밍 기어 브랜드 로캣과 파트너십 재계약 체결
# 동아에스티, 리베이트 의약품 과징금 108억+급여정지 1개월 처분
# 개미 은행주 대신 연 5%대 은행채 산다
# 테크랩스 점신, 서비스 통계 기반한 역술 기술 개편 진행
# 조선 상장기업 브랜드평판 5월 빅데이터 분석결과...1위 현대중공업, 2위 삼성...
# 에스디바이오, 대만 자가검사키트 공급계약 체결
# 브라질 산업자동화 산업 시장동향
# 산업은행 차기 회장 하마평...이석준·강석훈 거론, 부산 이전 추진 관건
# [리츠관련주] 대부분 하락속...에이리츠 홀로 0.78% 상승 '눈길'
# 에스디바이오센서, 1,033억 규모 대만 코로나19 자가검사키트 공급계약 체결
# '안개 속' 제주항공 UAM 뭔가 나와야 할 텐데...
# 화학 상장기업 브랜드평판 1~3위는
# MZ 세대의 나만 알고 있는 ‘찐’ 안주 맛집
# 하락장 와중에…나홀로 웃는 금융지주
# 마켓컬리 입주 포기에도··· 코람코에너지리츠, 다각화 전략 문제없는 이유
# SD바이오센서, 대만에 1033억 규모 자가검사키트 공급
# 하나금융·SK텔레콤·포스코…6월말 중간배당 매력 ‘쑥’
# [카드] 한국석유공업, PI첨단소재 '리사이클링 유기용제' 공급계약 체결
# 한화시스템·군인공제회…800억 밀리테크 펀드 조성
# 잇단 공정위 제재에도 또다시 제기된 갑질 의혹…홈플러스, 내부관리 부실에 ...
# 금융권, 희망퇴직 러시에도 인건비 감소 효과 미비···왜?
# sibal
# [특징주] 한국석유, 신규 사업 추진 가속화 될까..호재 소식에 주가는?
# [데스크 칼럼] '투기자본 먹잇감' 만드는 상속세율 뻔뻔스럽다
# 한국석유 주가 6%↑…PI첨단소재와 리사이클링 공급계약 소식에 강세
# GRDP로 본 16개 구군 간판기업…지역 특색 뚜렷
# [1분 환경] 오래된 밀폐용기 버리지 말고 '순환'시켜요
# 산업은행, 싱가포르서 벤처기업 투자 유치 행사 개최
# [키친쿡] 5월 2주, 엔데믹 나들이…파이렉스 외 3가지 주방용품
# “이래서 오너 리더십 필요” SK 계열사 90개 늘릴 때 삼성은 2개 감소 [비즈...
# 캠핑의 계절이 돌아왔다...위메프, 기획전으로 캠핑족 '유혹'
# 산업은행, '넥스트라운드싱가포르' 개최
# [Daily New유통] 이디야, CJ푸드빌, 유니클로 外
# [분석] CJ제일제당, 그린바이오 이익급증... 특별한 서프라이즈
# sibal
# sibal
# 산은, 싱가포르서 'KDB 넥스트라운드' 개최
# CJ제일제당, 바이오가 '효자'…1분기 영업익 전년比 13%↑
# [라이센스 커머스 PICK] G마켓·옥션·11번가 外
# 진천군 지방소멸시대 '역주행'… 93개월 연속 인구 증가
# [SR유통] 위메프, '차박&캠핑' 기획전 진행
# 진천군 지방소멸시대 `역주행'
# CJ제일제당, 1분기 매출 7조 달성…13% 늘어
# sibal
# 농협 익산시지부, 영농철 풍년농사 기원 일손돕기 실시
# NH농협 익산시지부, 영농철 풍년농사 기원 일손돕기 실시
# 진천군, 93개월 연속 인구 증가…비수도권 유일 기록
# '날개' 단 비비고 만두·햇반…CJ제일제당 성적도 '역대급'
# sibal
# sibal
# sibal
# '시총 100조 증발 사건'…삼성 SK, 이것에 당했다
# ‘검수완박’ 정국에서 다시 묻고 물어야 할 원칙
# 검찰, '라임사태' 이종필 前부사장 항소심서 징역 25년 구형
# sibal
# [업앤다운]게임주 하락…플레이위드만 유일하게 상승·52주최저가 속출
# 롯데리츠, 나도 리오프닝 ‘목표가 8천원’-이베스트證
# sibal
# 에듀윌, '2022 전기기능사 필기' 수험서 5월 1주 베스트셀러 1위 올라
# sibal
# 롯데리츠, 리테일 자산 투자 매력도 상승구간..‘매수’ 유지-이베스트[특징주] 성장주 잇단 신저가…카카오페이 공모가 근접(종합)
#
# 전기안전公 경북동부지사, 전기안전협의체 기술세미나 개최
# [게임 K-뉴딜] 최근 한달 시총 1조5100억 감소…크래프톤 1.79% 올라 상승률 ...
# 롯데리츠, 리오프닝 수혜 리츠-이베스트證
# sibal

# %%
def run(reset):
    # 계산된 횟수만 실행
    print("run")
    stock_information_getTime()
    while reset:
        get_companylist()
        print("남은횟수: ", reset)
        start = time.time()
        tuple_list=[]
        tuple_list.append(("stock" ,"title" ,"url" ,"date" ,"pov_or_neg"))
        id_key = 0
        st = time.time()
        #### Pool 프로세스 수는 변경 가능
        pool = ThreadPool(4)
        for _ in tqdm(pool.starmap(api_search, [(tuple_list, stock["stockName"], id_key) for stock in company],), total=len([(tuple_list, stock["stockName"], id_key) for stock in company])):
            pass

        pool.close()
        pool.join()
        print("quering end, it takes to ",int(time.time() -st),"s" )
        # 쿼링 포함 15분 제한
        print("sleep ")
        end = time.time()
        rest_time = 900 - (end-start) if 900-(end-start) >0 else 0
        time.sleep(rest_time) 

        reset -= 1

# %%
# 8시 20분에 주식가져옴
schedule.every().day.at("08:20").do(get_companylist)
# 8시 30분에 코드 실행
schedule.every().day.at("08:30").do(run, 31)

if __name__ == "__main__":
    print("start")
    # 주식 종목을 global로 설정
    get_companylist()
    '''
    now = datetime.datetime.now()
    time_now = datetime.timedelta(hours= now.hour , minutes=now.minute)
    time_start = datetime.timedelta(hours= 8, minutes=20)
    time_end = datetime.timedelta(hours= 15, minutes=30)
    #시간 계산해서 장 중일 때만 작동하도록..
    if (time_now > time_start) and (time_end > time_now):
        time_diff_s = (time_end-time_now).total_seconds()
        time_diff_m = time_diff_s/60
        run_time = int(time_diff_m/15)
    '''
    run(1)
    while True:
        schedule.run_pending()
        time.sleep(1)
# Out:
# start
# run
# 남은횟수:  1
# 100%|██████████| 942/942 [00:00<00:00, 1440406.26it/s]
# quering end, it takes to  299 s
# sleep
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/lwh/WORKSPACE/capstone-2022-07/model/capstone.ipynb Cell 21' in <cell line: 6>()
#      <a href='vscode-notebook-cell:/Users/lwh/WORKSPACE/capstone-2022-07/model/capstone.ipynb#ch0000020?line=21'>22</a> while True:
#      <a href='vscode-notebook-cell:/Users/lwh/WORKSPACE/capstone-2022-07/model/capstone.ipynb#ch0000020?line=22'>23</a>     schedule.run_pending()
# ---> <a href='vscode-notebook-cell:/Users/lwh/WORKSPACE/capstone-2022-07/model/capstone.ipynb#ch0000020?line=23'>24</a>     time.sleep(1)
#
# KeyboardInterrupt:
